# %%
import asyncpg
import asyncio
import os
import sys
sys.path.insert(0, os.path.abspath('..'))

# %%
from common.database import create_db_connection
from common import trading_data

# %%
loop = asyncio.get_event_loop()
loop.create_task(create_db_connection("postgresql://momentum@localhost/tradedb"))
# Out:
# <Task pending name='Task-47' coro=<create_db_connection() running at /Users/amichayoren/dev/algo/common/database.py:7>>
# db connection pool initialized

# %%
from common.market_data import calculate_trends, get_market_sectors, get_sector_tickers, get_market_industries

# %%
task = loop.create_task(get_market_sectors(trading_data.db_conn_pool))
sectors = await task
sectors
# Out:
# ['Real Estate',
#  'Healthcare',
#  'Health Technology',
#  'Energy',
#  'Utilities',
#  'Financial Services',
#  'Consumer Defensive',
#  'Technology Services',
#  'Communication Services',
#  'Process Industries',
#  'Producer Manufacturing',
#  'Basic Materials',
#  'Consumer Cyclical',
#  'Industrials',
#  'Technology']

# %%
task = loop.create_task(get_market_industries(trading_data.db_conn_pool))
industries = await task
industries
# Out:
# ['Agriculture',
#  'Medical Distribution',
#  'Oil & Gas - Drilling',
#  'Consulting & Outsourcing',
#  'Retail - Apparel & Specialty',
#  'Truck Manufacturing',
#  'Entertainment',
#  'Chemicals Specialty',
#  'Employment Services',
#  'Engineering & Construction',
#  'Travel & Leisure',
#  'Steel',
#  'Conglomerates',
#  'Insurance',
#  'Drug Manufacturers',
#  'Chemicals',
#  'Oil & Gas - Integrated',
#  'Computer Hardware',
#  'Restaurants',
#  'Coal',
#  'Personal Services',
#  'Transportation & Logistics',
#  'Medical Devices',
#  'Application Software',
#  'Homebuilding & Construction',
#  'REITs',
#  'Airlines',
#  'Oil & Gas - Refining & Marketing',
#  'Waste Management',
#  'Health Care Plans',
#  'Advertising & Marketing Services',
#  'Communication Services',
#  'Oil & Gas - Midstream',
#  'Utilities - Independent Power Producers',
#  'Pharmaceuticals Generic',
#  'Biotechnology',
#  'Consumer Packaged Goods',
#  'Retail - Defensive',
#  'Asset Management',
#  'Medical Diagnostics & Research',
#  'Pharmaceuticals Major',
#  'Forest Products',
#  'Online Media',
#  'Beverages - Alcoholic',
#  'Metals & Mining',
#  'Banks',
#  'Business Services',
#  'Building Materials',
#  'Medical Instruments & Equipment',
#  'Insurance - Life',
#  'Manufacturing - Apparel & Furniture',
#  'Autos',
#  'Oil & Gas - Services',
#  'Publishing',
#  'Brokers & Exchanges',
#  'Communication Equipment',
#  'Aerospace & Defense',
#  'Industrial Products',
#  'Insurance - Property & Casualty',
#  'Medical Specialties',
#  'Industrial Distribution',
#  'Health Care Providers',
#  'Credit Services',
#  'Packaging & Containers',
#  'Information Technology Services',
#  'Beverages - Non-Alcoholic',
#  'Oil & Gas - E&P',
#  'Tobacco Products',
#  'Real Estate Services',
#  'Farm & Construction Machinery',
#  'Insurance - Specialty',
#  'Pharmaceuticals Other',
#  'Industrial Machinery',
#  'Semiconductors',
#  'Utilities - Regulated',
#  'Education']

# %%
task = loop.create_task(get_sector_tickers(trading_data.db_conn_pool, 'Technology'))
sector_tickers = await task
sector_tickers
# Out:
# ['ATOM',
#  'AVNW',
#  'ACLS',
#  'ADTN',
#  'AIRG',
#  'AMOT',
#  'AAPL',
#  'AKAM',
#  'ACMR',
#  'ADSK',
#  'ALLT',
#  'ADBE',
#  'ALOT',
#  'AMBA',
#  'AOSL',
#  'ACIW',
#  'AEHR',
#  'ANSS',
#  'AEMD',
#  'APPN',
#  'AKTS',
#  'AEY',
#  'ALRM',
#  'ACIA',
#  'AMSWA',
#  'APWC',
#  'ALTR',
#  'AMBR',
#  'ANGI',
#  'AGYS',
#  'AMKR',
#  'ANY',
#  'APPS',
#  'AAOI',
#  'ACN',
#  'ADI',
#  'AEIS',
#  'AMD',
#  'AMRH',
#  'AMAT',
#  'APPF',
#  'ABIL',
#  'ATVI',
#  'ASYS',
#  'AXTI',
#  'ATHN',
#  'AMSC',
#  'ARRS',
#  'ASX',
#  'ATHM',
#  'AWRE',
#  'AVT',
#  'ARW',
#  'ASUR',
#  'BDR',
#  'ANET',
#  'APH',
#  'AUDC',
#  'BDC',
#  'APTI',
#  'AQ',
#  'BB',
#  'AYX',
#  'AVX',
#  'AUTO',
#  'BELFA',
#  'ATEN',
#  'AVID',
#  'BELFB',
#  'AYI',
#  'AZPN',
#  'ASML',
#  'AVGO',
#  'BAND',
#  'BCOV',
#  'ATTU',
#  'BBOX',
#  'BLKB',
#  'CSPI',
#  'COUP',
#  'CEVA',
#  'CLRO',
#  'CDNS',
#  'BNSO',
#  'CLDR',
#  'CDK',
#  'CRM',
#  'BHE',
#  'BKI',
#  'BNFT',
#  'CALX',
#  'BW',
#  'CACI',
#  'CARB',
#  'BIDU',
#  'CASA',
#  'CARG',
#  'CCUR',
#  'CAMP',
#  'CCMP',
#  'CAMT',
#  'BL',
#  'BSQR',
#  'CHKP',
#  'CDW',
#  'CIEN',
#  'BITA',
#  'BLIN',
#  'LRAD',
#  'CISN',
#  'BVSN',
#  'CMCM',
#  'BMI',
#  'BRKS',
#  'BOX',
#  'BRQS',
#  'KVHI',
#  'CCIH',
#  'COHR',
#  'BOXL',
#  'CLS',
#  'CGNX',
#  'CLFD',
#  'CERN',
#  'CNXN',
#  'DSPG',
#  'CRUS',
#  'CTG',
#  'CREE',
#  'DDD',
#  'DTRM',
#  'CYRN',
#  'COMM',
#  'CPSI',
#  'CYOU',
#  'CUI',
#  'DIOD',
#  'DGII',
#  'DAKT',
#  'COHU',
#  'CTRL',
#  'EA',
#  'CPSH',
#  'CVLT',
#  'DMRC',
#  'CMTL',
#  'DAIO',
#  'DWCH',
#  'CRCM',
#  'DPW',
#  'CSGS',
#  'CSLT',
#  'CNTF',
#  'DVMT',
#  'DYSL',
#  'CRAY',
#  'DLPN',
#  'EIGI',
#  'LITE',
#  'CPAH',
#  'CRTO',
#  'CRNT',
#  'ECOM',
#  'CSCO',
#  'DQ',
#  'DATA',
#  'EMKR',
#  'CSOD',
#  'CTXS',
#  'DCAR',
#  'CTS',
#  'EPAY',
#  'CTSH',
#  'CYBR',
#  'CSIQ',
#  'EFII',
#  'ERIC',
#  'DBD',
#  'DSGX',
#  'EGAN',
#  'DZSI',
#  'ENR',
#  'CY',
#  'CYBE',
#  'EGOV',
#  'DXC',
#  'DOX',
#  'EMAN',
#  'LFUS',
#  'EBIX',
#  'EXTR',
#  'LFIN',
#  'ENS',
#  'ELSE',
#  'FORTY',
#  'EVTC',
#  'FIT',
#  'FENG',
#  'ESP',
#  'EVBG',
#  'FTV',
#  'ELTK',
#  'ESE',
#  'FIVN',
#  'FTNW',
#  'FSLR',
#  'ELLI',
#  'FARO',
#  'ENPH',
#  'FFIV',
#  'EPAM',
#  'FEYE',
#  'FICO',
#  'EVOL',
#  'FN',
#  'FRSX',
#  'ENTG',
#  'FTEO',
#  'GDI',
#  'ESIO',
#  'LINK',
#  'FORM',
#  'EVH',
#  'FLEX',
#  'FEIM',
#  'EXFO',
#  'FB',
#  'FLIR',
#  'FNJN',
#  'FNSR',
#  'FSCT',
#  'GDDY',
#  'GWRE',
#  'GILT',
#  'HMNY',
#  'GVP',
#  'HRS',
#  'GDS',
#  'HSTM',
#  'GPRO',
#  'GSUM',
#  'HPE',
#  'HEAR',
#  'HUBB',
#  'IDTI',
#  'FTNT',
#  'HQCL',
#  'GRMN',
#  'INSG',
#  'GIGM',
#  'GRUB',
#  'HBB',
#  'IBM',
#  'GSB',
#  'GRPN',
#  'GRVY',
#  'GOOGL',
#  'HPJ',
#  'HUBS',
#  'IAC',
#  'GOOG',
#  'ICHR',
#  'HDP',
#  'IDN',
#  'GLOB',
#  'GIB',
#  'GLUU',
#  'GSIT',
#  'HIMX',
#  'INOD',
#  'HPQ',
#  'INOV',
#  'GLW',
#  'HQY',
#  'HLIT',
#  'HURC',
#  'ICAD',
#  'IIVI',
#  'HIVE',
#  'INTC',
#  'INVE',
#  'IIN',
#  'IVAC',
#  'KE',
#  'JCS',
#  'IMTE',
#  'KEM',
#  'INXN',
#  'IEC',
#  'ITI',
#  'JCOM',
#  'INST',
#  'IMPV',
#  'IT',
#  'KODK',
#  'IDSY',
#  'IRBT',
#  'INTU',
#  'IPDN',
#  'KLIC',
#  'KOPN',
#  'INFY',
#  'IMI',
#  'INS',
#  'KLAC',
#  'ITRN',
#  'LBCC',
#  'IMMR',
#  'INPX',
#  'IPHI',
#  'INAP',
#  'IOTS',
#  'INFN',
#  'ISDR',
#  'IZEA',
#  'KEYW',
#  'KN',
#  'ISNS',
#  'JTPY',
#  'KOSS',
#  'IMOS',
#  'LEXEA',
#  'JT',
#  'KEYS',
#  'KTCC',
#  'INTT',
#  'JNPR',
#  'JKS',
#  'IPGP',
#  'LDOS',
#  'JBL',
#  'LEDS',
#  'LEXEB',
#  'ITRI',
#  'LLNW',
#  'LGL',
#  'LPSN',
#  'MOXC',
#  'MAXR',
#  'NTNX',
#  'LRCX',
#  'MOMO',
#  'MANH',
#  'MU',
#  'MYSZ',
#  'LSCC',
#  'MPWR',
#  'NICE',
#  'NPTN',
#  'MANT',
#  'MTBCP',
#  'NCR',
#  'NTGR',
#  'LN',
#  'MLNX',
#  'MTLS',
#  'MSTR',
#  'MXL',
#  'MIXT',
#  'MRAM',
#  'NTIP',
#  'LORL',
#  'MCHP',
#  'MTSC',
#  'MXIM',
#  'MAMS',
#  'NETE',
#  'LTRX',
#  'MARK',
#  'NEWR',
#  'LTRPB',
#  'MOSY',
#  'MSFT',
#  'NOK',
#  'MIND',
#  'MTBC',
#  'LOGM',
#  'MOBL',
#  'NTCT',
#  'LOGI',
#  'LUNA',
#  'MDB',
#  'MITK',
#  'NTAP',
#  'MODN',
#  'OHGI',
#  'MEET',
#  'LPL',
#  'MEI',
#  'NSIT',
#  'LVHB',
#  'MXWL',
#  'NUAN',
#  'LXFT',
#  'NSYS',
#  'MJCO',
#  'MB',
#  'MINDP',
#  'MTCH',
#  'NCTY',
#  'NLST',
#  'LOV',
#  'NOVT',
#  'LPTH',
#  'MVIS',
#  'NH',
#  'NTWK',
#  'MDSO',
#  'MIME',
#  'MRCY',
#  'MDRX',
#  'MNDO',
#  'MFGP',
#  'MITL',
#  'LTRPA',
#  'MGIC',
#  'MRVL',
#  'MSN',
#  'NATI',
#  'MRIN',
#  'NNDM',
#  'MLAB',
#  'LYTS',
#  'MSI',
#  'MX',
#  'NTES',
#  'NANO',
#  'NEON',
#  'OTEX',
#  'OMCL',
#  'PI',
#  'NVEC',
#  'PCTY',
#  'ORBK',
#  'PPSI',
#  'ORCL',
#  'OIIM',
#  'SABR',
#  'PLAB',
#  'OSIS',
#  'PXLW',
#  'PKE',
#  'QNST',
#  'POWI',
#  'NVDA',
#  'PRCP',
#  'QCOM',
#  'PFPT',
#  'PINC',
#  'PLXS',
#  'QBAK',
#  'QTRH',
#  'OKTA',
#  'PAGS',
#  'OSS',
#  'PCYG',
#  'PRFT',
#  'SAP',
#  'PNTR',
#  'QRVO',
#  'NXPI',
#  'PERI',
#  'PAYC',
#  'PAR',
#  'PCTI',
#  'PLPC',
#  'PTC',
#  'PDFS',
#  'QUMU',
#  'OCC',
#  'QADA',
#  'OCLR',
#  'QTNA',
#  'PSTG',
#  'QUIK',
#  'OLED',
#  'PRO',
#  'PANW',
#  'PCOM',
#  'PLUS',
#  'PRGS',
#  'ON',
#  'PLT',
#  'RBCN',
#  'OESX',
#  'PEGA',
#  'QADB',
#  'QTWO',
#  'PSDO',
#  'PRKR',
#  'RELL',
#  'PLUG',
#  'RCM',
#  'RUBI',
#  'QLYS',
#  'REFR',
#  'RSYS',
#  'PYDS',
#  'RENN',
#  'RHT',
#  'RST',
#  'RESN',
#  'RUN',
#  'RFIL',
#  'RNET',
#  'RNWK',
#  'QTM',
#  'RPD',
#  'RNG',
#  'ROG',
#  'SAIL',
#  'RMBS',
#  'RDWR',
#  'RP',
#  'RMNI',
#  'RTEC',
#  'RVLT',
#  'SAIC',
#  'MKSI',
#  'MTSI',
#  'NOW',
#  'NVMI',
#  'SANM',
#  'SVT',
#  'TDY',
#  'SATS',
#  'STM',
#  'SE',
#  'SIGM',
#  'SMCI',
#  'SPWR',
#  'SPA',
#  'SWCH',
#  'TCX',
#  'SNCR',
#  'SOHU',
#  'SPRT',
#  'SSYS',
#  'SPNS',
#  'TDOC',
#  'SGLB',
#  'SOFO',
#  'SQNS',
#  'SWIR',
#  'TISA',
#  'SGOC',
#  'SNPS',
#  'SREV',
#  'SSNT',
#  'SYMC',
#  'SEAC',
#  'SILC',
#  'STX',
#  'TACT',
#  'SINA',
#  'TRNS',
#  'SUNW',
#  'SYKE',
#  'SSNC',
#  'SYNA',
#  'SCON',
#  'SNE',
#  'SPSC',
#  'SCSC',
#  'SQ',
#  'ST',
#  'SEND',
#  'STMP',
#  'TEL',
#  'SMTX',
#  'TNAV',
#  'STRM',
#  'SFUN',
#  'SHOP',
#  'SPLK',
#  'SEDG',
#  'SMTC',
#  'SIMO',
#  'SMI',
#  'SMIT',
#  'SOGO',
#  'SGMA',
#  'SLP',
#  'SNAP',
#  'SCKT',
#  'SLAB',
#  'SCWX',
#  'SSTI',
#  'SGH',
#  'SMSI',
#  'SOL',
#  'SYNC',
#  'SPI',
#  'TAIT',
#  'TSM',
#  'VRSN',
#  'TDC',
#  'TWLO',
#  'TXN',
#  'TECD',
#  'TTGT',
#  'TYPE',
#  'UPLD',
#  'USATP',
#  'TSRI',
#  'TCCO',
#  'VEEV',
#  'TSEM',
#  'VRNT',
#  'VUZI',
#  'SWKS',
#  'TEAM',
#  'TRMB',
#  'TTMI',
#  'TZOO',
#  'VIAV',
#  'VNET',
#  'TRT',
#  'TTWO',
#  'VICR',
#  'TLND',
#  'TYL',
#  'VVPR',
#  'WYY',
#  'TLRA',
#  'VHC',
#  'VSLR',
#  'TESS',
#  'TWTR',
#  'UCTT',
#  'TIVO',
#  'TRUE',
#  'WATT',
#  'UBNT',
#  'VECO',
#  'WB',
#  'WSTG',
#  'USAT',
#  'VSAT',
#  'WK',
#  'WSO',
#  'WIX',
#  'TRHC',
#  'VSH',
#  'TWOU',
#  'UEIC',
#  'TTD',
#  'VRTU',
#  'WSTL',
#  'ULTI',
#  'WUBA',
#  'XLNX',
#  'UMC',
#  'VERI',
#  'VJET',
#  'VPG',
#  'WIRE',
#  'XPER',
#  'VCRA',
#  'WDC',
#  'VRNS',
#  'XNET',
#  'WIT',
#  'VMW',
#  'YNDX',
#  'XOXO',
#  'XRX',
#  'YEXT',
#  'XGTI',
#  'ZNGA',
#  'WTT',
#  'WDAY',
#  'XELA',
#  'ZEN',
#  'ZIXI',
#  'YELP',
#  'ZDGE',
#  'YY',
#  'ZAYO',
#  'SSTK',
#  'TER',
#  'UIS']
